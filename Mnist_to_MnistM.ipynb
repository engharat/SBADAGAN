# %%
# %matplotlib inline
import os 
import argparse
import random
from main import train
random.seed()
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "0" #change to chosen GPU
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF

parser = argparse.ArgumentParser(description='Train model')                                                                       
parser.add_argument('--generator', type=str, default="upsampling", help="upsampling or deconv or subpixel")    
parser.add_argument('--discriminator', type=str, default="discriminator", help="discriminator discriminator_resnet")
parser.add_argument('--dset', type=str, default="VisDA2017", help="mnistM or washington_vandal50k or washington_vandal12classes")             
parser.add_argument('--img_dim', default=64, type=int, help="Image width == height")                           
parser.add_argument('--nb_epoch', default=100, type=int, help="Number of epochs")                              
parser.add_argument('--batch_size', default=64, type=int, help='Batch size for training purpose; for testing is hardcoded at 32')                                   
parser.add_argument('--n_batch_per_epoch', default=1000, type=int, help="Number of batch per epochs")           
parser.add_argument('--bn_mode', default=2, type=int, help="Batch norm mode")                                  
parser.add_argument('--noise_dim', default=100, type=int, help="noise sampler dimension")                      
parser.add_argument('--noise_scale', default=0.5, type=float, help="noise sampler variance")                   
parser.add_argument('--disc_iterations', default=5, type=int, help="Number of discriminator iterations")         
parser.add_argument('--opt_D', type=str, default="Adam", help="Optimizer for the discriminator")            
parser.add_argument('--opt_G', type=str, default="Adam", help="Optimizer for the generator")  
parser.add_argument('--opt_rec', type=str, default="Adam", help="Optimizer for the recostruction model")
parser.add_argument('--lr_D', type=float, default=1E-4, help="learning rate for the discriminator")            
parser.add_argument('--lr_G', type=float, default=1-4, help="learning rate for the generator")  
parser.add_argument('--lr_rec', type=float, default=1-4, help="learning rate for the recostruction model")
parser.add_argument('--use_mbd', action="store_true", help="use mini batch disc")
parser.add_argument('--deterministic1', action="store_true", help="remove the noise input to GAN1")
parser.add_argument('--deterministic2', action="store_true", help="remove the noise input to GAN2")
parser.add_argument('--inject_noise', action="store_true", help="inject noise into each layer")
parser.add_argument('--model', type=str, default="lsgan", help="wgan or lsgan") 
parser.add_argument('--no_supertrain', action="store_true", help="no discriminator supertraining") 
parser.add_argument('--pureGAN', action="store_true", help="no discriminator supertraining")
parser.add_argument('--lsmooth', type=float, default=1.0, help="label smoothing")
parser.add_argument('--monsterClass', action="store_true", help="Discriminator with 2x classes")
parser.add_argument('--disc_type', type=str, default="simple_disc", help="Discriminator type,between simple_disc or nclass_disc")
parser.add_argument('--resume', action="store_true", help="load GAN weights from previous train")
parser.add_argument('--name', type=str, default="mnist_mnistM_SGD", help="name of the run, used for saving and loading weights")
parser.add_argument('--wd', type=float, default=0.0, help="weight decay for generator/discriminator")
parser.add_argument('--history_size', type=float, default=1.8, help="history pool size = history_size * batch_size")
parser.add_argument('--data_aug', action="store_true", help="perform data augmentation on target dataset")
parser.add_argument('--reconst_w', type=float, default=1.0, help="reconstruction weight")
parser.add_argument('--rec', action="store_true", help="activate reconstruction between Gen1 and Gen2")
parser.add_argument('--reconstClass', type=float, default=0.0, help="activate reconstructionClass and set its weight")
parser.add_argument('--class_weight', type=float, default=1.0, help="class_weight")
parser.add_argument('--pretrained', action="store_true", help="use resnet50 pretrained on Imagenet")
parser.add_argument('--cArch', type=str, default="google", help="name of classifier architecture, google or signs")                           

args = parser.parse_args(' --img_dim 32 --cArch google  --dset mnistM --model lsgan --history_size 1.5 --no_supertrain \
                          --disc_type nclass_disc --class_weight 1.0 \
                           --reconstClass 1.0 --batch_size 32 --disc_iterations 1 --wd 1E-5 --lr_D 1E-4 --lr_G 1E-4'.split())
######
print args

assert args.opt_G in ["RMSprop", "SGD", "Adam"], "Unsupported optimizer"                 
assert args.opt_D in ["RMSprop", "SGD", "Adam"], "Unsupported optimizer" 

# Set the backend by modifying the env variable                                                                
                                                                            
os.environ["KERAS_BACKEND"] = "tensorflow"  
import keras.backend as K                                                                           
image_dim_ordering = "th"                                                                                  
K.set_image_dim_ordering(image_dim_ordering)

# Set default params
d_params = {"generator": args.generator,
            "discriminator": args.discriminator,
            "dset": args.dset,
            "img_dim": args.img_dim,
            "nb_epoch": args.nb_epoch,
            "batch_size": args.batch_size,
            "n_batch_per_epoch": args.n_batch_per_epoch,
            "bn_mode": args.bn_mode,
            "noise_dim": args.noise_dim,
            "noise_scale": args.noise_scale,
            "disc_iterations": args.disc_iterations,
            "lr_D": args.lr_D,
            "lr_G": args.lr_G,
            "lr_rec": args.lr_rec,
            "opt_rec": args.opt_rec,
            "opt_D": args.opt_D,
            "opt_G": args.opt_G,
            "use_mbd": args.use_mbd,
            "deterministic1": args.deterministic1,
            "deterministic2": args.deterministic2,
            "pureGAN": args.pureGAN,
            "lsmooth": args.lsmooth,
            "image_dim_ordering": image_dim_ordering,
            "model": args.model,
            "no_supertrain": args.no_supertrain,
            "monsterClass": args.monsterClass,
            "data_aug": args.data_aug,
            "disc_type": args.disc_type,
            "resume": args.resume,
            "name": args.name,
            "inject_noise": args.inject_noise,
            "history_size" : args.history_size,
            "reconst_w" : args.reconst_w,
            "class_weight" : args.class_weight,
            "rec" : args.rec,
            "reconstClass" : args.reconstClass,
            "pretrained" : args.pretrained,
            "cArch" : args.cArch,
            "wd" : args.wd
            }

# Launch training
train(**d_params)
# Out:
# Using TensorFlow backend.
# Namespace(batch_size=32, bn_mode=2, cArch='google', class_weight=1.0, data_aug=False, deterministic1=False, deterministic2=False, disc_iterations=1, disc_type='nclass_disc', discriminator='discriminator', dset='mnistM', generator='upsampling', history_size=1.5, img_dim=32, inject_noise=False, lr_D=0.0001, lr_G=0.0001, lr_rec=-3, lsmooth=1.0, model='lsgan', monsterClass=False, n_batch_per_epoch=1000, name='mnist_mnistM_SGD', nb_epoch=100, no_supertrain=True, noise_dim=100, noise_scale=0.5, opt_D='Adam', opt_G='Adam', opt_rec='Adam', pretrained=False, pureGAN=False, rec=False, reconstClass=1.0, reconst_w=1.0, resume=False, use_mbd=False, wd=1e-05)
#
# Experiment parameters:
# noise_dim 100
# reconstClass 1.0
# lsmooth 1.0
# wd 1e-05
# use_mbd False
# discriminator discriminator
# pureGAN False
# generator upsampling
# nb_epoch 100
# n_batch_per_epoch 1000
# disc_iterations 1
# history_size 1.5
# rec False
# class_weight 1.0
# monsterClass False
# opt_G Adam
# opt_D Adam
# resume False
# reconst_w 1.0
# deterministic1 False
# batch_size 32
# no_supertrain True
# deterministic2 False
# dset mnistM
# cArch google
# lr_rec -3
# opt_rec Adam
# data_aug False
# name mnist_mnistM_SGD
# noise_scale 0.5
# image_dim_ordering th
# bn_mode 2
# disc_type nclass_disc
# lr_G 0.0001
# img_dim 32
# lr_D 0.0001
# inject_noise False
# model lsgan
# pretrained False
# models.py:79: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(3920, kernel_regularizer=<keras.reg..., input_dim=(100,))`
#   x = Dense(5*s*s, input_dim=noise_dim,W_regularizer=l2(wd))(gen_noise_input)
# models.py:88: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   g = merge([gen_image_input, x], mode='concat',concat_axis=1) # because of concat_axis=1, will it work on tensorflow NHWC too?
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/keras/legacy/layers.py:460: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# models.py:90: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_regularizer=<keras.reg..., kernel_initializer="he_normal")`
#   x1 = Conv2D(64, (3, 3), border_mode='same', kernel_initializer="he_normal",W_regularizer=l2(wd))(g) #convolved by 3x3 filter to get 64x55x35
# models.py:94: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_regularizer=<keras.reg..., kernel_initializer="he_normal")`
#   x = Conv2D(64, (3, 3), border_mode='same', kernel_initializer="he_normal",W_regularizer=l2(wd))(x1)
# models.py:97: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_regularizer=<keras.reg..., kernel_initializer="he_normal")`
#   x = Conv2D(64, (3, 3), border_mode='same',  kernel_initializer="he_normal",W_regularizer=l2(wd))(x)
# models.py:99: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   x1 = merge([x, x1], mode='sum')
# models.py:103: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (1, 1), kernel_initializer="he_normal", name="gen_conv2d_final", padding="same", kernel_regularizer=<keras.reg...)`
#   x1 = Conv2D(output_channels, (1, 1),name="gen_conv2d_final", border_mode='same', kernel_initializer="he_normal",W_regularizer=l2(wd))(x1)
# models.py:106: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., name="generator_google1", inputs=[<tf.Tenso...)`
#   generator_model = Model(input=[gen_noise_input,gen_image_input], output=[x1], name="generator_google1")
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# generator_input (InputLayer)     (None, 100)           0
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 3920)          395920
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 5, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_image_input (InputLaye (None, 1, 28, 28)     0
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 5, 28, 28)     0
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 6, 28, 28)     0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 64, 28, 28)    3520
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_1 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_2 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_3 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_4 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_5 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_6 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_7 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_8 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# gen_conv2d_final (Conv2D)        (None, 3, 28, 28)     195
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 3, 28, 28)     0
# ====================================================================================================
# Total params: 697,107
# Trainable params: 696,083
# Non-trainable params: 1,024
# ____________________________________________________________________________________________________
# models.py:263: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_initializer=<keras.ini..., name="disc_conv2d_1", padding="same", strides=(2, 2), kernel_regularizer=<keras.reg...)`
#   border_mode="same", kernel_initializer=RandomNormal(stddev=0.02),kernel_regularizer=l2(wd))(disc_input)
# models.py:269: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_initializer=<keras.ini..., name="disc_conv2d_2", padding="same", strides=(2, 2), kernel_regularizer=<keras.reg...)`
#   border_mode="same", kernel_initializer=RandomNormal(stddev=0.02),kernel_regularizer=l2(wd))(x)
# models.py:274: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), kernel_initializer=<keras.ini..., name="finale_conv", padding="same", strides=(1, 1), kernel_regularizer=<keras.reg...)`
#   border_mode="same", kernel_initializer=RandomNormal(stddev=0.02),kernel_regularizer=l2(wd))(x)
# models.py:276: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="softmax", kernel_regularizer=<keras.reg..., name="auxiliary")`
#   aux = Dense(n_classes, activation='softmax', name='auxiliary',W_regularizer=l2(wd))(aux)
# models.py:278: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., name="discriminator_domain", inputs=[<tf.Tenso...)`
#   discriminator_model_domain = Model(input=[disc_input], output=[x], name="discriminator_domain")
# models.py:279: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., name="discriminator_class", inputs=[<tf.Tenso...)`
#   discriminator_model_class = Model(input=[disc_input], output=[aux], name="discriminator_class")
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 3, 28, 28)         0
# _________________________________________________________________
# disc_conv2d_1 (Conv2D)       (None, 64, 14, 14)        1792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 14, 14)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 14, 14)        0
# _________________________________________________________________
# disc_conv2d_2 (Conv2D)       (None, 128, 7, 7)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 7, 7)         512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 7, 7)         0
# _________________________________________________________________
# finale_conv (Conv2D)         (None, 1, 7, 7)           1153
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1)                 0
# =================================================================
# Total params: 77,569
# Trainable params: 77,185
# Non-trainable params: 384
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 3, 28, 28)         0
# _________________________________________________________________
# disc_conv2d_1 (Conv2D)       (None, 64, 14, 14)        1792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 14, 14)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 14, 14)        0
# _________________________________________________________________
# disc_conv2d_2 (Conv2D)       (None, 128, 7, 7)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 7, 7)         512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 7, 7)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# auxiliary (Dense)            (None, 10)                62730
# =================================================================
# Total params: 139,146
# Trainable params: 138,762
# Non-trainable params: 384
# _________________________________________________________________
# models.py:315: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), kernel_initializer="he_normal", name="conv1", padding="same", strides=(1, 1), kernel_regularizer=<keras.reg...)`
#   x = Conv2D(32, (5, 5), strides=(1, 1), name="conv1",border_mode="same", kernel_initializer="he_normal",kernel_regularizer=l2(wd))(input)
# models.py:318: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (5, 5), kernel_initializer="he_normal", name="conv2", padding="same", strides=(1, 1), kernel_regularizer=<keras.reg...)`
#   x = Conv2D(48, (5, 5), strides=(1, 1), name="conv2",border_mode="same", kernel_initializer="he_normal",kernel_regularizer=l2(wd))(x)
# models.py:322: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, kernel_initializer="he_normal", name="fc1", activation="relu", kernel_regularizer=<keras.reg...)`
#   x = Dense(100, init="he_normal",activation="relu", name='fc1',W_regularizer=l2(wd))(x)
# models.py:323: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(100, kernel_initializer="he_normal", name="fc2", activation="relu", kernel_regularizer=<keras.reg...)`
#   x = Dense(100, init="he_normal",activation="relu", name='fc2',W_regularizer=l2(wd))(x)
# models.py:324: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, kernel_initializer="he_normal", name="fc_softmax", activation="softmax", kernel_regularizer=<keras.reg...)`
#   x = Dense(n_classes, init="he_normal",activation="softmax", name='fc_softmax',W_regularizer=l2(wd))(x)
# models.py:325: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("fc..., name="classifier", inputs=Tensor("cl...)`
#   classifier_model = Model(input=input,output=x,name="classifier")
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# classifier_input (InputLayer (None, 3, 28, 28)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 28, 28)        2432
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 28, 28)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 14, 14)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 14, 14)        38448
# _________________________________________________________________
# activation_13 (Activation)   (None, 48, 14, 14)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 48, 7, 7)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 100)               235300
# _________________________________________________________________
# fc2 (Dense)                  (None, 100)               10100
# _________________________________________________________________
# fc_softmax (Dense)           (None, 10)                1010
# =================================================================
# Total params: 287,290
# Trainable params: 287,290
# Non-trainable params: 0
# _________________________________________________________________
# models.py:481: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("di..., inputs=[<tf.Tenso...)`
#   output=DCGAN_output)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 1, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_google1 (Model)        (None, 3, 28, 28)     697107
# ____________________________________________________________________________________________________
# discriminator_domain (Model)     (None, 1)             77569
# ====================================================================================================
# Total params: 774,676
# Trainable params: 773,268
# Non-trainable params: 1,408
# ____________________________________________________________________________________________________
# models.py:504: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("cl..., inputs=[<tf.Tenso...)`
#   output=DCGAN_output)
# additional_models.py:77: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., name="zClass", inputs=[<tf.Tenso...)`
#   zclass_model = Model(input=[generator.layers[0].input,image_input],output=[x],name="zClass")
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 1, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_google1 (Model)        (None, 3, 28, 28)     697107
# ____________________________________________________________________________________________________
# classifier (Model)               (None, 10)            287290
# ====================================================================================================
# Total params: 984,397
# Trainable params: 983,373
# Non-trainable params: 1,024
# ____________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3920)              395920
# _________________________________________________________________
# fc3 (Dense)                  (None, 100)               392100
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# fc4 (Dense)                  (None, 100)               10100
# =================================================================
# Total params: 798,120
# Trainable params: 798,120
# Non-trainable params: 0
# _________________________________________________________________
# Pretrain of discriminator finished.
# models.py:103: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (1, 1), kernel_initializer="he_normal", name="gen_conv2d_final", padding="same", kernel_regularizer=<keras.reg...)`
#   x1 = Conv2D(output_channels, (1, 1),name="gen_conv2d_final", border_mode='same', kernel_initializer="he_normal",W_regularizer=l2(wd))(x1)
# models.py:108: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., name="generator_google2", inputs=[<tf.Tenso...)`
#   generator_model = Model(input=[gen_noise_input,gen_image_input], output=[x1], name="generator_google2")
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# generator_input (InputLayer)     (None, 100)           0
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 3920)          395920
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 5, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_image_input (InputLaye (None, 3, 28, 28)     0
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 5, 28, 28)     0
# ____________________________________________________________________________________________________
# merge_6 (Merge)                  (None, 8, 28, 28)     0
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 64, 28, 28)    4672
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_9 (BatchNormGAN)  (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_10 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_11 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_12 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_8 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_13 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_14 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_9 (Merge)                  (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_15 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 64, 28, 28)    36928
# ____________________________________________________________________________________________________
# batch_norm_gan_16 (BatchNormGAN) (None, 64, 28, 28)    256
# ____________________________________________________________________________________________________
# merge_10 (Merge)                 (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 64, 28, 28)    0
# ____________________________________________________________________________________________________
# gen_conv2d_final (Conv2D)        (None, 1, 28, 28)     65
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 1, 28, 28)     0
# ====================================================================================================
# Total params: 698,129
# Trainable params: 697,105
# Non-trainable params: 1,024
# ____________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 1, 28, 28)         0
# _________________________________________________________________
# disc_conv2d_1 (Conv2D)       (None, 64, 14, 14)        640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 14, 14)        256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 14, 14)        0
# _________________________________________________________________
# disc_conv2d_2 (Conv2D)       (None, 128, 7, 7)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128, 7, 7)         512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128, 7, 7)         0
# _________________________________________________________________
# finale_conv (Conv2D)         (None, 1, 7, 7)           1153
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1)                 0
# =================================================================
# Total params: 76,417
# Trainable params: 76,033
# Non-trainable params: 384
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 1, 28, 28)         0
# _________________________________________________________________
# disc_conv2d_1 (Conv2D)       (None, 64, 14, 14)        640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 14, 14)        256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 14, 14)        0
# _________________________________________________________________
# disc_conv2d_2 (Conv2D)       (None, 128, 7, 7)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128, 7, 7)         512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128, 7, 7)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# auxiliary (Dense)            (None, 10)                62730
# =================================================================
# Total params: 137,994
# Trainable params: 137,610
# Non-trainable params: 384
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# classifier_input (InputLayer (None, 1, 28, 28)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 28, 28)        832
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 28, 28)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 14, 14)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 14, 14)        38448
# _________________________________________________________________
# activation_26 (Activation)   (None, 48, 14, 14)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 48, 7, 7)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 100)               235300
# _________________________________________________________________
# fc2 (Dense)                  (None, 100)               10100
# _________________________________________________________________
# fc_softmax (Dense)           (None, 10)                1010
# =================================================================
# Total params: 285,690
# Trainable params: 285,690
# Non-trainable params: 0
# _________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 3, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_google2 (Model)        (None, 1, 28, 28)     698129
# ____________________________________________________________________________________________________
# discriminator_domain (Model)     (None, 1)             76417
# ====================================================================================================
# Total params: 774,546
# Trainable params: 773,138
# Non-trainable params: 1,408
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 3, 28, 28)     0
# ____________________________________________________________________________________________________
# generator_google2 (Model)        (None, 1, 28, 28)     698129
# ____________________________________________________________________________________________________
# classifier (Model)               (None, 10)            285690
# ====================================================================================================
# Total params: 983,819
# Trainable params: 982,795
# Non-trainable params: 1,024
# ____________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3920)              395920
# _________________________________________________________________
# fc3 (Dense)                  (None, 100)               392100
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# fc4 (Dense)                  (None, 100)               10100
# =================================================================
# Total params: 798,120
# Trainable params: 798,120
# Non-trainable params: 0
# _________________________________________________________________
# Pretrain of discriminator finished.
# models.py:528: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("ge..., inputs=[<tf.Tenso...)`
#   output=reconstructor_output)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 1, 28, 28)     0
# ____________________________________________________________________________________________________
# noise_input2 (InputLayer)        (None, 100)           0
# ____________________________________________________________________________________________________
# generator_google1 (Model)        (None, 3, 28, 28)     697107
# ____________________________________________________________________________________________________
# generator_google2 (Model)        (None, 1, 28, 28)     698129
# ====================================================================================================
# Total params: 1,395,236
# Trainable params: 1,393,188
# Non-trainable params: 2,048
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 3, 28, 28)     0
# ____________________________________________________________________________________________________
# noise_input2 (InputLayer)        (None, 100)           0
# ____________________________________________________________________________________________________
# generator_google2 (Model)        (None, 1, 28, 28)     698129
# ____________________________________________________________________________________________________
# generator_google1 (Model)        (None, 3, 28, 28)     697107
# ====================================================================================================
# Total params: 1,395,236
# Trainable params: 1,393,188
# Non-trainable params: 2,048
# ____________________________________________________________________________________________________
# models.py:553: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("cl..., inputs=[<tf.Tenso...)`
#   output=recClass_output)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# noise_input (InputLayer)         (None, 100)           0
# ____________________________________________________________________________________________________
# image_input (InputLayer)         (None, 1, 28, 28)     0
# ____________________________________________________________________________________________________
# noise_input2 (InputLayer)        (None, 100)           0
# ____________________________________________________________________________________________________
# generator_google1 (Model)        (None, 3, 28, 28)     697107
# ____________________________________________________________________________________________________
# generator_google2 (Model)        (None, 1, 28, 28)     698129
# ____________________________________________________________________________________________________
# classifier (Model)               (None, 10)            285690
# ====================================================================================================
# Total params: 1,680,926
# Trainable params: 982,795
# Non-trainable params: 698,131
# ____________________________________________________________________________________________________
# 31968/32000 [============================>.] - ETA: 0s - Loss_D_real1: 0.0098 - Loss_D_gen1: 0.0079 - Loss_G1: 0.0679 - Loss_Classifier1: 0.0322 - Loss_D_real2: 0.0236 - Loss_D_gen2: 0.0239 - Loss_G2: 0.0338 - Loss_Classifier2: 0.0267 - Loss_Rec1: 0.0000e+00 - Loss_Rec2: 0.0000e+00 - Loss_GenClass1: 0.0382 - Loss_AutoLabel: 0.0389 - Loss_RecClass: 0.0466
# Dest labels:
# [4 7 1 0 1 6 1 0 0 7 9 5 8 2 0 3 7 9 7 2 7 7 5 6 3 4 6 8 7 8 2 0]
# Source labels:
# [9 9 3 8 5 0 8 9 7 0 4 4 8 3 6 7 1 8 4 9 9 1 0 0 3 2 3 2 9 9 6 9]
#
# Epoch 2, Time: 358.362437963
# epoch 1, Saved weights!
# Dest labels:
# [1 0 8 7 8 7 0 1 9 7 9 0 5 5 6 2 3 3 9 2 4 0 2 5 6 3 7 0 1 0 9 9]
# Source labels:
# [2 8 8 7 2 0 3 1 0 2 7 6 1 9 9 3 0 5 4 2 4 4 7 2 7 7 9 9 3 0 0 2]
#
# Epoch 2, Time: 362.798248053
# epoch 1, Saved weights!
# 10000/10000 [==============================] - 0s
#
#  Classifier Accuracy and loss on full target domain:  43.77%
#  9000/10000 [==========================>...] - ETA: 0s
#  Classifier Accuracy and loss on full target domain:  69.63%
#
#  Coeff: 0.000000 - score: 43.77
#
#  Coeff: 0.100000 - score: 47.07
#
#  Coeff: 0.200000 - score: 51.71
#
#  Coeff: 0.300000 - score: 57.70
#
#  Coeff: 0.400000 - score: 63.00
#
#  Coeff: 0.500000 - score: 67.44
#
#  Coeff: 0.600000 - score: 68.88
#
#  Coeff: 0.700000 - score: 69.34
#
#  Coeff: 0.800000 - score: 69.62
#
#  Coeff: 0.900000 - score: 69.66
#
#  Coeff: 1.000000 - score: 69.63
# 31968/32000 [============================>.] - ETA: 0s - Loss_D_real1: 0.0099 - Loss_D_gen1: 0.0084 - Loss_G1: 0.0650 - Loss_Classifier1: 0.0179 - Loss_D_real2: 0.0247 - Loss_D_gen2: 0.0247 - Loss_G2: 0.0308 - Loss_Classifier2: 0.0085 - Loss_Rec1: 0.0000e+00 - Loss_Rec2: 0.0000e+00 - Loss_GenClass1: 0.0251 - Loss_AutoLabel: 0.0213 - Loss_RecClass: 0.0293
# Dest labels:
# [9 6 0 7 0 4 0 8 3 3 9 4 6 4 6 0 5 9 5 1 3 8 1 6 6 8 5 0 0 1 8 1]
# Source labels:
# [2 1 9 8 5 7 3 7 6 9 9 5 5 0 6 5 0 8 8 7 1 0 2 4 4 9 6 8 0 4 5 3]
#
# Epoch 3, Time: 354.145318985
# epoch 2, Saved weights!
# Dest labels:
# [7 7 4 2 9 8 2 5 4 1 9 1 6 3 6 0 0 0 3 5 0 4 7 8 8 4 2 6 8 2 2 3]
# Source labels:
# [3 4 6 3 7 3 0 4 6 0 8 9 0 8 2 5 0 5 9 4 0 5 7 7 5 4 2 4 7 6 6 5]
#
# Epoch 3, Time: 354.82129693
# epoch 2, Saved weights!
#  8000/10000 [=======================>......] - ETA: 0s
#  Classifier Accuracy and loss on full target domain:  59.32%
#  9000/10000 [==========================>...] - ETA: 0s
#  Classifier Accuracy and loss on full target domain:  73.97%
#
#  Coeff: 0.000000 - score: 59.32
#
#  Coeff: 0.100000 - score: 61.62
#
#  Coeff: 0.200000 - score: 64.32
#
#  Coeff: 0.300000 - score: 67.48
#
#  Coeff: 0.400000 - score: 70.65
#
#  Coeff: 0.500000 - score: 73.34
#
#  Coeff: 0.600000 - score: 73.98
#
#  Coeff: 0.700000 - score: 73.94
#
#  Coeff: 0.800000 - score: 74.01
#
#  Coeff: 0.900000 - score: 73.92
#
#  Coeff: 1.000000 - score: 73.97
# 27712/32000 [========================>.....] - ETA: 47s - Loss_D_real1: 0.0090 - Loss_D_gen1: 0.0077 - Loss_G1: 0.0668 - Loss_Classifier1: 0.0143 - Loss_D_real2: 0.0251 - Loss_D_gen2: 0.0250 - Loss_G2: 0.0301 - Loss_Classifier2: 0.0067 - Loss_Rec1: 0.0000e+00 - Loss_Rec2: 0.0000e+00 - Loss_GenClass1: 0.0221 - Loss_AutoLabel: 0.0178 - Loss_RecClass: 0.0268
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-397a18f574ca> in <module>()
#     107
#     108 # Launch training
# --> 109 train(**d_params)
#
# /home/paolo/sbadagan/sbadagan.pyc in train(**kwargs)
#     594         while batch_counter < n_batch_per_epoch:
#     595             l_disc_real1, l_disc_gen1, l_gen1, l_z1, l_class1,l_rec1,l_GenClass1,_ = get_loss_list()
# --> 596             A_data_batch, A_labels_batch, B_data_batch, B_labels_batch = train_gan(GAN1, GAN1.disc_iters, A_data, A_labels, B_data, B_labels, batch_counter, l_disc_real1, l_disc_gen1, l_gen1,l_GenClass1, class_weight)
#     597
#     598             l_disc_real2, l_disc_gen2, l_gen2, l_z2, l_class2, l_rec2, l_GenClass2, l_recClass = get_loss_list()
#
# /home/paolo/sbadagan/sbadagan.pyc in train_gan(GAN, disc_iters, A_data, A_labels, B_data, B_labels, batch_counter, l_disc_real, l_disc_gen, l_gen, l_GenClass, class_weight)
#     323         elif GAN.disc_type == "nclass_disc":
#     324             gen_loss =  GAN.DCGAN_model.train_on_batch([X_noise,X_source_batch], np.ones(GAN.batch_size)) #TRYING SAME BATCH OF DISC
# --> 325             GenClass_loss =  GAN.GenClass_model.train_on_batch([X_noise,X_source_batch], Y_source_batch,sample_weight=np.ones(GAN.batch_size)*class_weight)
#     326             #gen_loss = gen_loss[0]
#     327         l_gen.appendleft(gen_loss)
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1619             ins = x + y + sample_weights
#    1620         self._make_train_function()
# -> 1621         outputs = self.train_function(ins)
#    1622         if len(outputs) == 1:
#    1623             return outputs[0]
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/paolo/.virtualenvs/keras2.1/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
